# %% [markdown]
# Simple Graph using langgraph. Workflow without an LLM
#
# 1. Nodes - Simple python functions performing some task
# 2. Edges - Connect the nodes. Conditional edge will have 2 options to go either way
# 3. State - State serves as the input for nodes & Edges
# 4. StateGraph -

# %% [markdown]
# ### Build a simple workflow or Graph Using LangGraph

# %%
print("Hi")
# Out:
# Hi

# %%
from typing_extensions import TypedDict

class State(TypedDict):
    graph_info : str
